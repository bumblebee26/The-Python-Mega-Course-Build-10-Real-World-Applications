# %% [markdown]
# # Application 3 - Building a Website Blocker

# %% [markdown]
# ### Application Architecture

# %% [markdown]
# Open the given path in your computer : C:\Windows\System32\drivers\etc
#
# You will find a 'hosts' file, open it with Microsoft Word.
# Here, add the IP address and Web-link of the pages you want to block.

# %% [markdown]
# The file is displayed as below --

# %%
file=open("hosts_temp","r")

# %% [markdown]
# #### Initially working with copy of the 'hosts' file in the other directory.

# %%
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost

# %% [markdown]
# ##### We can add the links to block manually here by appending the above text with the IP address and the web-link of the page, to be blocked.

# %% [markdown]
# ### For eg:

# %%
file=open("hosts_temp","a")  ##a=append
file.write("\n127.0.0.1       www.facebook.com")
# Out:
# 33

# %%
file.close()

# %%
file=open("hosts_temp","r")
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost
# 127.0.0.1       www.facebook.com

# %%
file.close()

# %% [markdown]
# ##### In this application, we perform the above task using Python.

# %% [markdown]
# ### Setting up the Script

# %%
import time

hosts_path="C:\Windows\System32\drivers\etc\hosts";
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]

# %% [markdown]
# ### Adding the Blocking period

# %%
import time
from datetime import datetime as dt

dt.now()
# Out:
# datetime.datetime(2019, 6, 18, 16, 35, 13, 301358)

# %%
dt.now() < dt(2019, 6, 17, 15)
# Out:
# False

# %%
dt.now() > dt(2019, 6, 17, 15)
# Out:
# True

# %%
import time
from datetime import datetime as dt

hosts_path="C:\Windows\System32\drivers\etc\hosts";
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]

dt.now()

while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,16):
        print("Working hours. . .")
    else:
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Fun hours. . .
# Fun hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-51811d956f7a> in <module>
#      14     else:
#      15         print("Fun hours. . .")
# ---> 16     time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Editing  the hosts file using File Handling

# %%
import time
from datetime import datetime as dt

hst="hosts"
hosts_path="C:\Windows\System32\drivers\etc\hosts"
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]


while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,16):
        print("Working hours. . .")
        with open(hst,'r+') as file:
            content=file.read()
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirects+" "+ website+"\n")
    else:
        with open(hst,'r+') as file:
            content=file.readlines()
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Fun hours. . .
# Fun hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d9e69529f350> in <module>
#      26                     file.write(line)
#      27         print("Fun hours. . .")
# ---> 28     time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Adding truncation

# %%
import time
from datetime import datetime as dt

hst="hosts"
hosts_path="C:\Windows\System32\drivers\etc\hosts"
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]


while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,16):
        print("Working hours. . .")
        with open(hst,'r+') as file:
            content=file.read()
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirect+" "+ website+"\n")
    else:
        with open(hst,'r+') as file:
            content=file.readlines()
            file.seek(0)
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate()
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Fun hours. . .
# Fun hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-3aeb046dd9e6> in <module>
#      28             file.truncate()
#      29         print("Fun hours. . .")
# ---> 30     time.sleep(5)
#
# KeyboardInterrupt:

# %%
file=open("hosts","r")
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost

# %% [markdown]
# ## Here, we can see for the 'Fun Hours' the 'hosts' file removes/unblocks the blocked website.

# %%
import time
from datetime import datetime as dt

hst="hosts"
hosts_path="C:\Windows\System32\drivers\etc\hosts"
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]


while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,18):
        print("Working hours. . .")
        with open(hst,'r+') as file:
            content=file.read()
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirect+" "+ website+"\n")
    else:
        with open(hst,'r+') as file:
            content=file.readlines()
            file.seek(0)
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate()
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Working hours. . .
# Working hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-5005b37f8201> in <module>
#      28             file.truncate()
#      29         print("Fun hours. . .")
# ---> 30     time.sleep(5)
#
# KeyboardInterrupt:

# %%
file=open("hosts","r")
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost
# 127.0.0.1 www.facebook.com
# 127.0.0.1 www.github.com
# 127.0.0.1 facebook.com
# 127.0.0.1 github.com

# %% [markdown]
# ## Here, we can see for the 'Working Hours' the 'hosts' file adds/blocks the mentioned website.

# %% [markdown]
# ### Now make the changes to the original 'host file'

# %%
import time
from datetime import datetime as dt

hst="hosts"
hosts_path="C:\Windows\System32\drivers\etc\hosts"
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]


while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,18):
        print("Working hours. . .")
        with open(hosts_path,'r+') as file:
            content=file.read()
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirect+" "+ website+"\n")
    else:
        with open(hosts_path,'r+') as file:
            content=file.readlines()
            file.seek(0)
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate()
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Working hours. . .
# Working hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-e278c44631ac> in <module>
#      28             file.truncate()
#      29         print("Fun hours. . .")
# ---> 30     time.sleep(5)
#
# KeyboardInterrupt:

# %%
file=open("C:\Windows\System32\drivers\etc\hosts","r")
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost
# 127.0.0.1 www.facebook.com
# 127.0.0.1 www.github.com
# 127.0.0.1 facebook.com
# 127.0.0.1 github.com

# %%
import time
from datetime import datetime as dt

hst="hosts"
hosts_path="C:\Windows\System32\drivers\etc\hosts"
redirect="127.0.0.1"          ##Error Page

website_list=["www.facebook.com","www.github.com","facebook.com","github.com"]


while True: 
    if dt(dt.now().year, dt.now().month, dt.now().day,8) < dt.now() < dt(dt.now().year,dt.now().month,dt.now().day,16):
        print("Working hours. . .")
        with open(hosts_path,'r+') as file:
            content=file.read()
            for website in website_list:
                if website in content:
                    pass
                else:
                    file.write(redirect+" "+ website+"\n")
    else:
        with open(hosts_path,'r+') as file:
            content=file.readlines()
            file.seek(0)
            for line in content:
                if not any(website in line for website in website_list):
                    file.write(line)
            file.truncate()
        print("Fun hours. . .")
    time.sleep(5)
# Out:
# Fun hours. . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-359a5f1fe9a6> in <module>
#      28             file.truncate()
#      29         print("Fun hours. . .")
# ---> 30     time.sleep(5)
#
# KeyboardInterrupt:

# %%
file=open("C:\Windows\System32\drivers\etc\hosts","r")
content=file.read()
print(content)
# Out:
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost

# %% [markdown]
# ### Scheduling the Program

# %%
from IPython.display import Image
Image("task_setting1.png")
### Step 1   

## Also, possible in Markdown cells
##    ![title](a.png)

# %%
Image("task_setting2.png")
### Step 2

# %%
Image("task_setting3.png")
### Step 3

# %%
Image("task_setting4.png")
### Step 4

# %%
Image("task_setting5.png")
### Step 5

# %% [markdown]
# #### You can enable and disable the task directly from here. Also, do run the program in 'Fun Hours' in the final run, so when you disable the task, the 'hosts' file is unchanged (no websites to be blocked).
#
# #### Else you can just edit the 'hosts' file directly from the path.
