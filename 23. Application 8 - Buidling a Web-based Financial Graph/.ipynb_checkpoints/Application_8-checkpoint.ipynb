# %% [markdown]
# # Buidling a Web-based Financial Graph

# %%
# importing required libraries
from pandas_datareader import data
import datetime
from bokeh.plotting import figure, show, output_file

# %%
start=datetime.datetime(2016,3,2)
end=datetime.datetime(2016,3,10)

df=data.DataReader(name="GOOG",data_source="yahoo",start=start,end=end)

# %%
df
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2016-03-01  718.809998  699.770020  703.619995  718.809998  2151400
# 2016-03-02  720.000000  712.000000  719.000000  718.849976  1629000
# 2016-03-03  719.450012  706.020020  718.679993  712.419983  1958000
# 2016-03-04  716.489990  706.020020  714.989990  710.890015  1972100
# 2016-03-07  708.091003  686.900024  706.900024  695.159973  2985100
# 2016-03-08  703.789978  685.340027  688.590027  693.969971  2076300
# 2016-03-09  705.679993  694.000000  698.469971  705.239990  1421500
# 2016-03-10  716.440002  703.359985  708.119995  712.820007  2833500
#
#              Adj Close
# Date
# 2016-03-01  718.809998
# 2016-03-02  718.849976
# 2016-03-03  712.419983
# 2016-03-04  710.890015
# 2016-03-07  695.159973
# 2016-03-08  693.969971
# 2016-03-09  705.239990
# 2016-03-10  712.820007

# %%
df.index[df.Close > df.Open]
# Out:
# DatetimeIndex(['2016-03-01', '2016-03-08', '2016-03-09', '2016-03-10'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
p=figure(x_axis_type='datetime',width=1000,height=300, tag="Candlestick Chart")

hours_12=12*60*60*1000; # milliseconds

# p.rect(x-axis parameter, y-axis paramter - midpoint of the rectangle, spacing incrementer(12 hours), height of rectangle, color)
p.rect(df.index[df.Close > df.Open],(df.Open + df.Close)/2, hours_12, abs(df.Open - df.Close))

output_file("Candlestick.html")

show(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-079da9406435> in <module>
# ----> 1 p=figure(x_axis_type='datetime',width=1000,height=300, tag="Candlestick Chart")
#       2
#       3 hours_12=12*60*60*1000; # milliseconds
#       4
#       5 # p.rect(x-axis parameter, y-axis paramter - midpoint of the rectangle, spacing incrementer(12 hours), height of rectangle, color)
#
# ~\Anaconda3\lib\site-packages\bokeh\plotting\figure.py in figure(**kwargs)
#     982
#     983 def figure(**kwargs):
# --> 984     return Figure(**kwargs)
#     985 figure.__doc__ = Figure.__doc__
#     986
#
# ~\Anaconda3\lib\site-packages\bokeh\plotting\figure.py in __init__(self, *arg, **kw)
#     148             kw['title'] = Title(text=title)
#     149
# --> 150         super(Figure, self).__init__(*arg, **kw)
#     151
#     152         self.x_range = _get_range(opts.x_range)
#
# ~\Anaconda3\lib\site-packages\bokeh\model.py in __init__(self, **kwargs)
#     259         self._document = None
#     260         self._temp_document = None
# --> 261         super(Model, self).__init__(**kwargs)
#     262         default_theme.apply_to_model(self)
#     263
#
# ~\Anaconda3\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     251
#     252         for name, value in properties.items():
# --> 253             setattr(self, name, value)
#     254
#     255     def __setattr__(self, name, value):
#
# ~\Anaconda3\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     286
#     287             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 288                 (name, self.__class__.__name__, text, nice_join(matches)))
#     289
#     290     def __str__(self):
#
# AttributeError: unexpected attribute 'tag' to Figure, similar attributes are tags
